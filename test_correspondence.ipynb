# %%
import torch
from diff3f import get_features_per_vertex
from time import time
from utils import convert_mesh_container_to_torch_mesh, cosine_similarity, double_plot, get_colors, generate_colors
from dataloaders.mesh_container import MeshContainer
from diffusion import init_pipe
from dino import init_dino
from functional_map import compute_surface_map
import os
# Out:
# WARNING[XFORMERS]: xFormers can't load C++/CUDA extensions. xFormers was built for:
#     PyTorch 2.3.0.post101 with CUDA None (you have 2.1.0+cu121)
#     Python  3.10.14 (you have 3.10.19)
#   Please reinstall xformers (see https://github.com/facebookresearch/xformers#installing-xformers)
#   Memory-efficient attention, SwiGLU, sparse and more won't be available.
#   Set XFORMERS_MORE_DETAILS=1 for more details

# %%
device = torch.device('cuda:0')
torch.cuda.set_device(device)
num_views = 100
H = 512
W = 512
num_images_per_prompt = 1
tolerance = 0.004
random_seed = 42
use_normal_map = True

# %%
def compute_features(device, pipe, dino_model, m, prompt):
    mesh = convert_mesh_container_to_torch_mesh(m, device=device, is_tosca=False)
    mesh_vertices = mesh.verts_list()[0]
    features = get_features_per_vertex(
        device=device,
        pipe=pipe, 
        dino_model=dino_model,
        mesh=mesh,
        prompt=prompt,
        mesh_vertices=mesh_vertices,
        num_views=num_views,
        H=H,
        W=W,
        tolerance=tolerance,
        num_images_per_prompt=num_images_per_prompt,
        use_normal_map=use_normal_map,
    )
    return features.cpu()

# %%
pipe = init_pipe(device)
os.environ["XFORMERS_DISABLED"] = '1'
dino_model = init_dino(device)
# Out:
# /home/junhokim/miniconda3/envs/diff3f/lib/python3.10/site-packages/diffusers/configuration_utils.py:239: FutureWarning: It is deprecated to pass a pretrained model name or path to `from_config`.If you were trying to load a model, please use <class 'unet_2d_condition.UNet2DConditionModel'>.load_config(...) followed by <class 'unet_2d_condition.UNet2DConditionModel'>.from_config(...) instead. Otherwise, please make sure to pass a configuration dictionary instead. This functionality will be removed in v1.0.0.
#   deprecate("config-passed-as-path", "1.0.0", deprecation_message, standard_warn=False)
# Loading pipeline components...:   0%|          | 0/6 [00:00<?, ?it/s]
# You have disabled the safety checker for <class 'pipeline_controlnet_img2img.StableDiffusionControlNetImg2ImgPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# Using cache found in /home/junhokim/.cache/torch/hub/facebookresearch_dinov2_main
# /home/junhokim/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:45: UserWarning: xFormers is disabled (SwiGLU)
#   warnings.warn("xFormers is disabled (SwiGLU)")
# /home/junhokim/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:51: UserWarning: xFormers is not available (SwiGLU)
#   warnings.warn("xFormers is not available (SwiGLU)")
# /home/junhokim/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:29: UserWarning: xFormers is disabled (Attention)
#   warnings.warn("xFormers is disabled (Attention)")
# /home/junhokim/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:33: UserWarning: xFormers is not available (Attention)
#   warnings.warn("xFormers is not available (Attention)")
# /home/junhokim/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:35: UserWarning: xFormers is disabled (Block)
#   warnings.warn("xFormers is disabled (Block)")
# /home/junhokim/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:40: UserWarning: xFormers is not available (Block)
#   warnings.warn("xFormers is not available (Block)")

# %%
source_file_path = "meshes/chair_1_rot_45.obj"
target_file_path = "meshes/chair_2.obj"
source_mesh = MeshContainer().load_from_file(source_file_path)
target_mesh = MeshContainer().load_from_file(target_file_path)

# %%
f_source = compute_features(device, pipe, dino_model, source_mesh, "chair")
# Out:
# Rendering complete
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [06:17<00:00,  3.77s/it]
# Number of missing features:  620
# Copied features from nearest vertices
# Time taken in mins:  6.54892239967982

# %%
f_target = compute_features(device, pipe, dino_model, target_mesh, "chair")
# Out:
# Rendering complete
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [06:20<00:00,  3.80s/it]
# Number of missing features:  4
# Copied features from nearest vertices
# Time taken in mins:  6.365933227539062

# %%
s = cosine_similarity(f_source.to(device),f_target.to(device))
s = torch.argmax(s, dim=0).cpu().numpy()
cmap_source = get_colors(source_mesh.vert); cmap_target = cmap_source[s]

# %%
double_plot(source_mesh,target_mesh,cmap_source,cmap_target)
# Out:
# HBox(children=(Output(), Output()))
# HBox(children=(Output(), Output()))

# %% [markdown]
# # Apply functional map on features

# %%
source_file_path = "meshes/cat.off"
target_file_path = "meshes/lion.off"
source_mesh = MeshContainer().load_from_file(source_file_path)
target_mesh = MeshContainer().load_from_file(target_file_path)
f_source = compute_features(device, pipe, dino_model, source_mesh, "cat")
f_target = compute_features(device, pipe, dino_model, target_mesh, "lion")
# Out:
# Rendering complete
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [06:05<00:00,  3.66s/it]
# Number of missing features:  140
# Copied features from nearest vertices
# Time taken in mins:  6.495763293902079
# Rendering complete
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [06:11<00:00,  3.72s/it]
# Number of missing features:  17
# Copied features from nearest vertices
# Time taken in mins:  6.476000332832337

# %%
s = cosine_similarity(f_source.to(device),f_target.to(device))
s = torch.argmax(s, dim=0).cpu().numpy()
cmap_source = get_colors(source_mesh.vert); cmap_target = cmap_source[s]
double_plot(source_mesh,target_mesh,cmap_source,cmap_target)
# Out:
# HBox(children=(Output(), Output()))
# HBox(children=(Output(), Output()))

# %%
surface_map = compute_surface_map(source_file_path, target_file_path, f_source.numpy(), f_target.numpy())
# Out:
# mesh1 (4638, 3)
# mesh2 (259, 3)
#
# Computing Laplacian spectrum
# Computing 200 eigenvectors
# 	Done in 2.12 s
# Computing 200 eigenvectors
# Problem during LBO decomposition ! Please check
# /home/junhokim/Projects/Diffusion-3D-Features/pyFM/mesh/laplacian.py:121: RuntimeWarning: divide by zero encountered in divide
#   S = 0.5 * S / np.sqrt(1-S**2)
# /home/junhokim/Projects/Diffusion-3D-Features/pyFM/mesh/laplacian.py:151: UserWarning: The problem size 259 minus the constraints size 0 is too small relative to the block size 200. Using a dense eigensolver instead of LOBPCG iterations.No output of the history of the iterations.
#   eigenvalues, eigenvectors = sparse.linalg.lobpcg(W, init_eigenvecs,
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/Projects/Diffusion-3D-Features/pyFM/mesh/laplacian.py:143, in laplacian_spectrum(W, A, spectrum_size)
#     142 try:
# --> 143     eigenvalues, eigenvectors = sparse.linalg.eigsh(W, k=spectrum_size, M=A,
#     144                                                     sigma=-0.01)
#     146 except RuntimeError:
#     147     # raise ValueError('Matrices are not positive semidefinite')
#     148     # Initial eigenvector values:
#
# File ~/miniconda3/envs/diff3f/lib/python3.10/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:1651, in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1650 if OPinv is None:
# -> 1651     Minv_matvec = get_OPinv_matvec(A, M, sigma,
#    1652                                    hermitian=True, tol=tol)
#    1653 else:
#
# File ~/miniconda3/envs/diff3f/lib/python3.10/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:1093, in get_OPinv_matvec(A, M, sigma, hermitian, tol)
#    1092 OP = _fast_spmatrix_to_csc(OP, hermitian=hermitian)
# -> 1093 return SpLuInv(OP).matvec
#
# File ~/miniconda3/envs/diff3f/lib/python3.10/site-packages/scipy/sparse/linalg/_eigen/arpack/arpack.py:915, in SpLuInv.__init__(self, M)
#     914 def __init__(self, M):
# --> 915     self.M_lu = splu(M)
#     916     self.shape = M.shape
#
# File ~/miniconda3/envs/diff3f/lib/python3.10/site-packages/scipy/sparse/linalg/_dsolve/linsolve.py:413, in splu(A, permc_spec, diag_pivot_thresh, relax, panel_size, options)
#     411     _options["SymmetricMode"] = True
# --> 413 return _superlu.gstrf(N, A.nnz, A.data, A.indices, A.indptr,
#     414                       csc_construct_func=csc_construct_func,
#     415                       ilu=False, options=_options)
#
# RuntimeError: Factor is exactly singular
#
# During handling of the above exception, another exception occurred:
#
# LinAlgError                               Traceback (most recent call last)
# File ~/miniconda3/envs/diff3f/lib/python3.10/site-packages/scipy/sparse/linalg/_eigen/lobpcg/lobpcg.py:466, in lobpcg(A, X, B, M, Y, tol, maxiter, largest, verbosityLevel, retLambdaHistory, retResidualNormsHistory, restartControl)
#     465 try:
# --> 466     vals, vecs = eigh(A,
#     467                       B,
#     468                       subset_by_index=eigvals,
#     469                       check_finite=False)
#     470     if largest:
#     471         # Reverse order to be compatible with eigs() in 'LM' mode.
#
# File ~/miniconda3/envs/diff3f/lib/python3.10/site-packages/scipy/linalg/_decomp.py:594, in eigh(a, b, lower, eigvals_only, overwrite_a, overwrite_b, turbo, eigvals, type, check_finite, subset_by_index, subset_by_value, driver)
#     593 elif info > n:
# --> 594     raise LinAlgError('The leading minor of order {} of B is not '
#     595                       'positive definite. The factorization of B '
#     596                       'could not be completed and no eigenvalues '
#     597                       'or eigenvectors were computed.'.format(info-n))
#     598 else:
#
# LinAlgError: The leading minor of order 258 of B is not positive definite. The factorization of B could not be completed and no eigenvalues or eigenvectors were computed.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 surface_map = compute_surface_map(source_file_path, target_file_path, f_source.numpy(), f_target.numpy())
#
# File ~/Projects/Diffusion-3D-Features/functional_map.py:31, in compute_surface_map(path_1, path_2, c1, c2, source_index, target_index, use_wks, device)
#      22     process_params = {
#      23     'n_ev': (50,50),  # Number of eigenvalues on source and Target
#      24     'n_descr': 2048,
#    (...)
#      28     'subsample_step': 0
#      29     }
#      30 model = FunctionalMapping(mesh1, mesh2)
# ---> 31 model.preprocess(**process_params,verbose=True)
#      32 fit_params = {
#      33 'w_descr': 1e0,
#      34 'w_lap': 1e-2,
#      35 'w_dcomm': 1e-1,
#      36 'w_orient': 0
#      37 }
#      38 model.fit(**fit_params, verbose=True)
#
# File ~/Projects/Diffusion-3D-Features/pyFM/functional.py:218, in FunctionalMapping.preprocess(self, n_ev, n_descr, descr_type, landmarks, subsample_step, k_process, verbose, descr1, descr2)
#     216     print('\nComputing Laplacian spectrum')
#     217 self.mesh1.process(max(self.k1, k_process), verbose=verbose)
# --> 218 self.mesh2.process(max(self.k2, k_process), verbose=verbose)
#     220 if verbose:
#     221     print('\nComputing descriptors')
#
# File ~/Projects/Diffusion-3D-Features/pyFM/mesh/trimesh.py:399, in TriMesh.process(self, k, skip_normals, intrinsic, robust, verbose)
#     397     if self.facelist is None:
#     398         robust = True
# --> 399     self.laplacian_spectrum(k, return_spectrum=False, intrinsic=intrinsic, robust=robust,
#     400                             verbose=verbose)
#     402 return self
#
# File ~/Projects/Diffusion-3D-Features/pyFM/mesh/trimesh.py:367, in TriMesh.laplacian_spectrum(self, k, intrinsic, return_spectrum, robust, verbose)
#     365     print(f"Computing {k} eigenvectors")
#     366     start_time = time.time()
# --> 367 self.eigenvalues, self.eigenvectors = laplacian.laplacian_spectrum(self.W, self.A,
#     368                                                                    spectrum_size=k)
#     370 if verbose:
#     371     print(f"\tDone in {time.time()-start_time:.2f} s")
#
# File ~/Projects/Diffusion-3D-Features/pyFM/mesh/laplacian.py:151, in laplacian_spectrum(W, A, spectrum_size)
#     149 print('Problem during LBO decomposition ! Please check')
#     150 init_eigenvecs = np.random.random((A.shape[0], spectrum_size))
# --> 151 eigenvalues, eigenvectors = sparse.linalg.lobpcg(W, init_eigenvecs,
#     152                                                  B=A, largest=False, maxiter=40)
#     154 eigenvalues = np.real(eigenvalues)
#     155 sorting_arr = np.argsort(eigenvalues)
#
# File ~/miniconda3/envs/diff3f/lib/python3.10/site-packages/scipy/sparse/linalg/_eigen/lobpcg/lobpcg.py:477, in lobpcg(A, X, B, M, Y, tol, maxiter, largest, verbosityLevel, retLambdaHistory, retResidualNormsHistory, restartControl)
#     475         return vals, vecs
#     476     except Exception as e:
# --> 477         raise Exception(
#     478             f"Dense eigensolver failed with error\n"
#     479             f"{e}\n"
#     480         )
#     482 if (residualTolerance is None) or (residualTolerance <= 0.0):
#     483     residualTolerance = np.sqrt(np.finfo(blockVectorX.dtype).eps) * n
#
# Exception: Dense eigensolver failed with error
# The leading minor of order 258 of B is not positive definite. The factorization of B could not be completed and no eigenvalues or eigenvectors were computed.

# %%
cmap_source = get_colors(source_mesh.vert); cmap_target = cmap_source[surface_map.cpu().numpy()]
double_plot(source_mesh,target_mesh,cmap_source,cmap_target)
# Out:
# HBox(children=(Output(), Output()))
# HBox(children=(Output(), Output()))

# %% [markdown]
# # Part segmentation

# %%
from sklearn.cluster import KMeans
import numpy as np

k = 6

kmeans = KMeans(n_clusters=k, random_state=0, n_init="auto").fit(f_source)

segments1 = kmeans.predict(f_source)

# Apply centroids on another mesh to segment it in a corresponding manner
segments2 = kmeans.predict(f_target)

# %%
segment_colors = generate_colors(k)
cmap_source = np.array([segment_colors[j] for j in segments1])
cmap_target = np.array([segment_colors[j] for j in segments2])

# %%
double_plot(source_mesh,target_mesh,cmap_source,cmap_target)
# Out:
# HBox(children=(Output(), Output()))
# HBox(children=(Output(), Output()))

# %%
source_file_path = "meshes/posed_human.off"
target_file_path = "meshes/cat.off"
source_mesh = MeshContainer().load_from_file(source_file_path)
target_mesh = MeshContainer().load_from_file(target_file_path)
f_source = compute_features(device, pipe, dino_model, source_mesh, "naked human")
f_target = compute_features(device, pipe, dino_model, target_mesh, "cat")
# Out:
# Rendering complete
# 100%|██████████| 100/100 [03:13<00:00,  1.93s/it]
# Number of missing features:  3
# Time taken in mins:  3.3452319582303365
# Rendering complete
# 100%|██████████| 100/100 [03:17<00:00,  1.97s/it]
# Number of missing features:  140
# Time taken in mins:  3.4606642444928486

# %%
k = 6

kmeans = KMeans(n_clusters=k, random_state=0, n_init="auto").fit(f_source)

segments1 = kmeans.predict(f_source)

# Apply centroids on another mesh to segment it in a corresponding manner

segments2 = kmeans.predict(f_target)
segment_colors = generate_colors(k)
cmap_source = np.array([segment_colors[j] for j in segments1])
cmap_target = np.array([segment_colors[j] for j in segments2])

# %%
double_plot(source_mesh,target_mesh,cmap_source,cmap_target)
# Out:
# HBox(children=(Output(), Output()))
# HBox(children=(Output(), Output()))
